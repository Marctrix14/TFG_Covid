# %% [markdown]
# Autor: Marc Padrós Jiménez

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# !pip install -q tf-nightly-2.0-preview
# %load_ext tensorboard
# Out:
# The tensorboard extension is already loaded. To reload it, use:
#   %reload_ext tensorboard

# %%
import os, sys, datetime
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import tensorflow as tf
from tensorflow.keras import *
import keras
import h5py

# from keras.models import Sequential
# from keras.layers import Dense, Dropout, Flatten
# from keras.layers import Conv2D, MaxPooling2D

from random import shuffle

from IPython.display import display
from IPython.display import Image as _Imgdis
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

# %%
#from google.colab import drive, files
#drive.mount('/content/gdrive', force_remount=True)

# %%
# dataset source - https://www.kaggle.com/epreis/rxtorax 

# Drive version
#effusion_train_test_dataset_dir = '/content/gdrive/My Drive/Colab Notebooks/TFG/PleuralEffusion/dataset/train_test/effusion'
#normal_train_test_dataset_dir = '/content/gdrive/My Drive/Colab Notebooks/TFG/PleuralEffusion/dataset/train_test/normal'

# Local version
effusion_train_test_dataset_dir = 'dataset/train_test/effusion'
normal_train_test_dataset_dir = 'dataset/train_test/normal'

# %%
all_effusion_images = [f for f in os.listdir(effusion_train_test_dataset_dir) if os.path.isfile(os.path.join(effusion_train_test_dataset_dir, f))]
all_normal_images = [f for f in os.listdir(normal_train_test_dataset_dir) if os.path.isfile(os.path.join(normal_train_test_dataset_dir, f))]

print("Number of effusion samples: "+str(len(all_effusion_images)))
print("Number of normal samples: "+str(len(all_normal_images)))
# Out:
# Number of effusion samples: 496
# Number of normal samples: 496

# %%
for i in range(0,1):
  img = mpimg.imread(effusion_train_test_dataset_dir + "/" + all_effusion_images[i])
  imgplot = plt.imshow(img)
  plt.show()

# %%
for i in range(0,1):
  img = mpimg.imread(normal_train_test_dataset_dir + "/" + all_normal_images[i])
  imgplot = plt.imshow(img)
  plt.show()

# %%
# combining normal and effusion samples

all_samples = []
effusion_samples = []
normal_samples = []  

for sample in all_effusion_images:
  effusion_samples.append(effusion_train_test_dataset_dir + "/" + sample)

for sample in all_normal_images:
  normal_samples.append(normal_train_test_dataset_dir + "/" + sample)

all_samples = effusion_samples + normal_samples
shuffle(all_samples)

# %%
print(effusion_samples[0])
print(normal_samples[0])
print("Total samples: " + str(len(all_samples)))
# Out:
# dataset/train_test/effusion/effusion0.png
# dataset/train_test/normal/normal0.png
# Total samples: 992

# %%
# splitting images into features and labels
# loading all images into an ndarray

features_dirs = all_samples
y = []

channels = 1
im_height = 64
im_width = 64

image_array = np.ndarray(shape = (len(all_samples), 
                                  im_height,
                                  im_width, 
                                  channels),
                         dtype = np.float32)
i = 0

for sample in features_dirs:
    
    img = load_img(sample, grayscale=True)
    img.thumbnail((im_width, im_height))
    x = img_to_array(img)  
    x = x.reshape((64, 64, 1))
    image_array[i] = x
    i+=1
    
    # 0 = normal; 1 = effusion
    if 'normal' in sample: 
      y.append(0)
    else:
      y.append(1)
      
y = np.array((y))

# %%
# saving loaded dataset as a 

with h5py.File('X.h5', 'w') as X_hdf5:
  X_hdf5.create_dataset('X', data = image_array)
  
with h5py.File('y.h5', 'w') as y_hdf5:
  y_hdf5.create_dataset('y', data = y)

# %%
with h5py.File('X.h5', 'r') as hf:
    image_array_h5 = hf['X'][:]
    
with h5py.File('y.h5', 'r') as hf:
    y_h5 = hf['y'][:]

print("Features shape: " + str(image_array_h5.shape))
print("Labels shape: " + str(y_h5.shape))
# Out:
# Features shape: (992, 64, 64, 1)
# Labels shape: (992,)

# %%
X_train, X_test, y_train, y_test = train_test_split(image_array, y, test_size = 0.2, random_state = 0)

# %%
num_classes = 2
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %%
def conv_model():
  model = Sequential()

  model.add(layers.Convolution2D(64, kernel_size=(3, 3),
                   activation='relu',
                   input_shape=(64,64,1)))
  
  model.add(layers.Convolution2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPool2D(pool_size=(2, 2)))
  model.add(layers.Dropout(0.5))
  
  model.add(layers.Convolution2D(64, (3, 3), activation='relu'))
  model.add(layers.MaxPool2D(pool_size=(2, 2)))
  model.add(layers.Dropout(0.5))

  model.add(layers.Flatten())

  model.add(layers.Dense(128, activation='relu'))
  model.add(layers.Dropout(0.5))
  model.add(layers.Dense(num_classes, activation='softmax'))
  
  return model

# %%
model = conv_model()
tf.keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model/model_to_dot to work.

# %%
model.compile(loss = tf.keras.losses.categorical_crossentropy,
              optimizer = tf.keras.optimizers.Adam(),
              metrics=['accuracy'])

# logdir = os.path.join("logs", datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
# tensorboard_callback = tf.keras.callbacks.TensorBoard(logdir, histogram_freq=1)

# %tensorboard --logdir logs

model.fit(X_train, y_train,
          batch_size=64,
          epochs=200,
          verbose=1,
          validation_data=(X_test, y_test))

score = model.evaluate(X_test, y_test, verbose=0)

print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# Epoch 1/200
# 13/13 [==============================] - 6s 381ms/step - loss: 24.2791 - accuracy: 0.4956 - val_loss: 0.6983 - val_accuracy: 0.5276
# Epoch 2/200
# 13/13 [==============================] - 5s 363ms/step - loss: 0.7129 - accuracy: 0.4931 - val_loss: 0.6933 - val_accuracy: 0.5276
# Epoch 3/200
# 13/13 [==============================] - 5s 373ms/step - loss: 0.6949 - accuracy: 0.4830 - val_loss: 0.6925 - val_accuracy: 0.5528
# Epoch 4/200
# 13/13 [==============================] - 5s 357ms/step - loss: 0.6925 - accuracy: 0.5069 - val_loss: 0.6932 - val_accuracy: 0.4824
# Epoch 5/200
# 13/13 [==============================] - 5s 348ms/step - loss: 0.6921 - accuracy: 0.5473 - val_loss: 0.6933 - val_accuracy: 0.4774
# Epoch 6/200
# 13/13 [==============================] - 5s 350ms/step - loss: 0.6923 - accuracy: 0.5498 - val_loss: 0.6928 - val_accuracy: 0.5327
# Epoch 7/200
# 13/13 [==============================] - 5s 350ms/step - loss: 0.6910 - accuracy: 0.5359 - val_loss: 0.6924 - val_accuracy: 0.6080
# Epoch 8/200
# 13/13 [==============================] - 5s 351ms/step - loss: 0.6836 - accuracy: 0.5649 - val_loss: 0.6911 - val_accuracy: 0.5327
# Epoch 9/200
# 13/13 [==============================] - 5s 358ms/step - loss: 0.6791 - accuracy: 0.5561 - val_loss: 0.6931 - val_accuracy: 0.4824
# Epoch 10/200
# 13/13 [==============================] - 5s 357ms/step - loss: 0.6821 - accuracy: 0.5675 - val_loss: 0.6862 - val_accuracy: 0.6332
# Epoch 11/200
# 13/13 [==============================] - 5s 356ms/step - loss: 0.6837 - accuracy: 0.5700 - val_loss: 0.6943 - val_accuracy: 0.4724
# Epoch 12/200
# 13/13 [==============================] - 5s 353ms/step - loss: 0.6782 - accuracy: 0.5712 - val_loss: 0.6912 - val_accuracy: 0.5276
# Epoch 13/200
# 13/13 [==============================] - 5s 359ms/step - loss: 0.6729 - accuracy: 0.5939 - val_loss: 0.6865 - val_accuracy: 0.6281
# Epoch 14/200
# 13/13 [==============================] - 5s 355ms/step - loss: 0.6658 - accuracy: 0.6192 - val_loss: 0.6837 - val_accuracy: 0.6382
# Epoch 15/200
# 13/13 [==============================] - 5s 354ms/step - loss: 0.6668 - accuracy: 0.6040 - val_loss: 0.6896 - val_accuracy: 0.5226
# Epoch 16/200
# 13/13 [==============================] - 5s 365ms/step - loss: 0
200
# 13/13 [==============================] - 5s 378ms/step - loss: 0.6381 - accuracy: 0.6280 - val_loss: 0.6603 - val_accuracy: 0.5930
# Epoch 41/200
# 13/13 [==============================] - 5s 374ms/step - loss: 0.6402 - accuracy: 0.6192 - val_loss: 0.6616 - val_accuracy: 0.6030
# Epoch 42/200
# 13/13 [==============================] - 5s 375ms/step - loss: 0.6283 - accuracy: 0.6608 - val_loss: 0.6546 - val_accuracy: 0.5879
# Epoch 43/200
# 13/13 [==============================] - 5s 373ms/step - loss: 0.6051 - accuracy: 0.6734 - val_loss: 0.6554 - val_accuracy: 0.5879
# Epoch 44/200
# 13/13 [==============================] - 5s 365ms/step - loss: 0.6235 - accuracy: 0.6507 - val_loss: 0.6531 - val_accuracy: 0.5779
# Epoch 45/200
# 13/13 [==============================] - 5s 367ms/step - loss: 0.6476 - accuracy: 0.6230 - val_loss: 0.6532 - val_accuracy: 0.6231
# Epoch 46/200
# 13/13 [==============================] - 5s 372ms/step - loss: 0.6423 - accuracy: 0.6343 - val_loss: 0.6524 - val_accuracy: 0.6432
# Epoch 47/200
# 13/13 [==============================] - 5s 381ms/step - loss: 0.6261 - accuracy: 0.6772 - val_loss: 0.6608 - val_accuracy: 0.6131
# Epoch 48/200
# 13/13 [==============================] - 5s 374ms/step - loss: 0.6467 - accuracy: 0.6368 - val_loss: 0.6566 - val_accuracy: 0.6281
# Epoch 49/200
# 13/13 [==============================] - 5s 374ms/step - loss: 0.6284 - accuracy: 0.6620 - val_loss: 0.6629 - val_accuracy: 0.6131
# Epoch 50/200
# 13/13 [==============================] - 5s 375ms/step - loss: 0.6312 - accuracy: 0.6494 - val_loss: 0.6506 - val_accuracy: 0.6432
# Epoch 51/200
# 13/13 [==============================] - 5s 367ms/step - loss: 0.6314 - accuracy: 0.6507 - val_loss: 0.6892 - val_accuracy: 0.5427
# Epoch 52/200
# 13/13 [==============================] - 5s 366ms/step - loss: 0.6316 - accuracy: 0.6494 - val_loss: 0.6448 - val_accuracy: 0.6533
# Epoch 53/200
# 13/13 [==============================] - 5s 370ms/step - loss: 0.6293 - accuracy: 0.6494 - val_loss: 0.6559 - val_accuracy: 0.6131
# Epoch 54/200
# 13/13 [==============================] - 5s 377ms/step - loss: 0.6285 - accuracy: 0.6520 - val_loss: 0.6684 - val_accuracy: 0.5628
# Epoch 55/200
# 13/13 [==============================] - 5s 368ms/step - loss: 0.6388 - accuracy: 0.6482 - val_loss: 0.6762 - val_accuracy: 0.5477
# Epoch 56/200
# 13/13 [==============================] - 5s 368ms/step - loss: 0.6330 - accuracy: 0.6482 - val_loss: 0.6582 - val_accuracy: 0.5879
# Epoch 57/200
# 13/13 [==============================] - 5s 379ms/step - loss: 0.6129 - accuracy: 0.6709 - val_loss: 0.6567 - val_accuracy: 0.5829
# Epoch 58/200
# 13/13 [==============================] - 5s 364ms/step - loss: 0.6051 - accuracy: 0.6709 - val_loss: 0.6782 - val_accuracy: 0.5477
# Epoch 59/200
# 13/13 [==============================] - 5s 366ms/step - loss: 0.6237 - accuracy: 0.6393 - val_loss: 0.6688 - val_accuracy: 0.5729
# Epoch 60/200
# 13/13 [==============================] - 5s 367ms/step - loss: 0.6220 - accuracy: 0.6482 - val_loss: 0.6592 - val_accuracy: 0.5980
# Epoch 61/200
# 13/13 [==============================] - 5s 372ms/step - loss: 0.6134 - accuracy: 0.6696 - val_loss: 0.6562 - val_accuracy: 0.5879
# Epoch 62/200
# 13/13 [==============================] - 5s 369ms/step - loss: 0.6200 - accuracy: 0.6494 - val_loss: 0.6704 - val_accuracy: 0.5578
# Epoch 63/200
# 13/13 [==============================] - 5s 369ms/step - loss: 0.6482 - accuracy: 0.6053 - val_loss: 0.6812 - val_accuracy: 0.5528
# Epoch 64/200
# 13/13 [==============================] - 5s 361ms/step - loss: 0.6052 - accuracy: 0.6520 - val_loss: 0.6642 - val_accuracy: 0.5779
# Epoch 65/200
# 13/13 [==============================] - 5s 367ms/step - loss: 0.6206 - accuracy: 0.6469 - val_loss: 0.6516 - val_accuracy: 0.5930
# Epoch 66/200
# 13/13 [==============================] - 5s 385ms/step - loss: 0.6094 - accuracy: 0.6620 - val_loss: 0.6568 - val_accuracy: 0.5628
# Epoch 67/200
# 13/13 [==============================] - 5s 378ms/step - loss: 0.6469 - accuracy: 0.6028 - val_loss: 0.6720 - val_accuracy: 0.5678
# Epoch 68/200
# 13/13 [==============================] - 5s 377ms/step - loss: 0
200
# 13/13 [==============================] - 5s 365ms/step - loss: 0.5311 - accuracy: 0.7264 - val_loss: 0.6744 - val_accuracy: 0.6382
# Epoch 193/200
# 13/13 [==============================] - 5s 365ms/step - loss: 0.5539 - accuracy: 0.7175 - val_loss: 0.6802 - val_accuracy: 0.6181
# Epoch 194/200
# 13/13 [==============================] - 5s 363ms/step - loss: 0.5596 - accuracy: 0.6974 - val_loss: 0.6941 - val_accuracy: 0.6181
# Epoch 195/200
# 13/13 [==============================] - 5s 366ms/step - loss: 0.5331 - accuracy: 0.7201 - val_loss: 0.6313 - val_accuracy: 0.6432
# Epoch 196/200
# 13/13 [==============================] - 5s 375ms/step - loss: 0.5654 - accuracy: 0.7074 - val_loss: 0.6536 - val_accuracy: 0.6030
# Epoch 197/200
# 13/13 [==============================] - 5s 381ms/step - loss: 0.5494 - accuracy: 0.7339 - val_loss: 0.6224 - val_accuracy: 0.6533
# Epoch 198/200
# 13/13 [==============================] - 5s 390ms/step - loss: 0.5509 - accuracy: 0.7175 - val_loss: 0.6469 - val_accuracy: 0.6131
# Epoch 199/200
# 13/13 [==============================] - 5s 412ms/step - loss: 0.5232 - accuracy: 0.7339 - val_loss: 0.6486 - val_accuracy: 0.6131
# Epoch 200/200
# 13/13 [==============================] - 6s 425ms/step - loss: 0.5444 - accuracy: 0.7125 - val_loss: 0.6589 - val_accuracy: 0.6332
# Test loss: 0.6588807702064514
# Test accuracy: 0.6331658363342285

# %%
model.save("model.h5")
# DRIVE version
# files.download('model.h5')
#files.download('X.h5')
#files.download('y.h5')

# %%
def plot_figures(figures, n_rows, n_cols):

    fig, axes = plt.subplots(ncols = n_cols, 
                                 nrows = n_rows)
    for ind, title in enumerate(figures):
        axes.ravel()[ind].imshow(figures[title], 
                                     cmap=plt.gray())
        axes.ravel()[ind].set_title(title)
        axes.ravel()[ind].set_axis_off()
    plt.tight_layout()

# %%
def img_to_numpy_array(img_object):
  img = load_img(img_object, grayscale=True)
  img.thumbnail((im_width, im_height))
  x = img_to_array(img)  
  x = x.reshape((1, 64, 64, 1))
  return x

# %%
# Drive version
#test_effusion_dir = '/content/gdrive/My Drive/Colab Notebooks/dataset/validation/effusion'
#test_normal_dir = '/content/gdrive/My Drive/Colab Notebooks/dataset/validation/normal'

# Local version
test_effusion_dir = 'dataset/validation/effusion'
test_normal_dir = 'dataset/validation/normal'

total_effusion_test_images = [f for f in os.listdir(test_effusion_dir) if os.path.isfile(os.path.join(test_effusion_dir, f))]
total_normal_test_images = [f for f in os.listdir(test_normal_dir) if os.path.isfile(os.path.join(test_normal_dir, f))]

effusion_figures_list = []
normal_figures_list = []
prediction_effusion = []
prediction_normal = []

for i in range(len(total_effusion_test_images)):
  effusion_img_path = test_effusion_dir + '/' + total_effusion_test_images[i]
  normal_img_path = test_normal_dir + '/' + total_normal_test_images[i]
  img1 = mpimg.imread(effusion_img_path)
  img2 = mpimg.imread(normal_img_path)  
  effusion_array = img_to_numpy_array(effusion_img_path)
  normal_array = img_to_numpy_array(normal_img_path)
  prediction_effusion.append(1 if model.predict(effusion_array)[0][0] > 0.5 else 0)
  prediction_normal.append(1 if model.predict(normal_array)[0][0] > 0.5 else 0)
  effusion_figures_list.append(img1)
  normal_figures_list.append(img2)
  
number_of_im = 4
effusion_figures = {'e '+str(i)+'predicted '+str(prediction_effusion[i]): effusion_figures_list[i] for i in range(number_of_im)}
normal_figures = {'n '+str(i)+'predicted '+str(prediction_normal[i]): normal_figures_list[i] for i in range(number_of_im)}

plot_figures(effusion_figures, 1, 4)  
plot_figures(normal_figures, 1, 4)
